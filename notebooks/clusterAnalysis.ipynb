# %%
from functions.kMC import kMC
from main import csv_file_path
from list_of_attributes import list_of_attributes
import numpy as np

# %%
# 4
# Gender Spendingscore Clustering

attribute = list_of_attributes[4]
data = kMC('not needed', csv_file_path, attribute)

print(data)
# Out:
# (0      0
# 1      1
# 2      2
# 3      1
# 4      0
#       ..
# 195    1
# 196    2
# 197    1
# 198    2
# 199    1
# Name: Cluster, Length: 200, dtype: int32, array([[ 0.58947368, 48.35789474],
#        [ 0.56896552, 82.06896552],
#        [ 0.4893617 , 14.59574468]]))
